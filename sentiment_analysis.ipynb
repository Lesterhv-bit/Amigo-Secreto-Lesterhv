# %% [markdown]
# <a href="https://colab.research.google.com/github/Lesterhv-bit/Amigo-Secreto-Lesterhv/blob/main/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hola Equipo');
# Out:
# Hola Equipo
